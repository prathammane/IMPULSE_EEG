# %% [markdown]
# # TASK 10.A

# %%
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Synthetic Data Generation for EEG Data Using VAE (MSE , cosine similarity and correlation)

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers
from sklearn.metrics import mean_squared_error
from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import pearsonr
# Define paths
base_path = "drive/MyDrive/EEG_Data/train_data"
save_base_path = "drive/MyDrive/EEG_Data/synthetic_data"
os.makedirs(save_base_path, exist_ok=True)

# List of folders (classes) in train_data
folders = [f for f in os.listdir(base_path) if os.path.isdir(os.path.join(base_path, f))]

# Define VAE class

class VAE(tf.keras.Model):
    def __init__(self, latent_dim, input_dim):
        super(VAE, self).__init__()
        self.latent_dim = latent_dim

        # Encoder
        self.encoder = tf.keras.Sequential([
            layers.InputLayer(input_shape=(input_dim,)),
            layers.Dense(128, activation='relu'),
            layers.Dense(64, activation='relu'),
            layers.Dense(latent_dim * 2),  # Outputs z_mean and z_log_var
        ])

        # Decoder
        self.decoder = tf.keras.Sequential([
            layers.InputLayer(input_shape=(latent_dim,)),
            layers.Dense(64, activation='relu'),
            layers.Dense(128, activation='relu'),
            layers.Dense(input_dim, activation='sigmoid'),
        ])

    def encode(self, x):
        z_mean, z_log_var = tf.split(self.encoder(x), num_or_size_splits=2, axis=1)
        return z_mean, z_log_var

    def reparameterize(self, z_mean, z_log_var):
        epsilon = tf.random.normal(shape=tf.shape(z_mean))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

    def decode(self, z):
        return self.decoder(z)

    def train_step(self, data):
        if isinstance(data, tuple):
            x = data[0]
        else:
            x = data

        with tf.GradientTape() as tape:
            # Forward pass
            z_mean, z_log_var = self.encode(x)
            z = self.reparameterize(z_mean, z_log_var)
            x_reconstructed = self.decode(z)

            # Reconstruction loss (MSE)
            reconstruction_loss = tf.reduce_mean(tf.square(x - x_reconstructed))

            # KL divergence loss
            kl_loss = -0.5 * tf.reduce_sum(
                1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var), axis=1
            )
            kl_loss = tf.reduce_mean(kl_loss)

            # Total loss
            total_loss = reconstruction_loss + kl_loss

        # Backpropagation
        gradients = tape.gradient(total_loss, self.trainable_variables)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_variables))

        # Return a dictionary of metrics
        return {"loss": total_loss, "reconstruction_loss": reconstruction_loss, "kl_loss": kl_loss}


def generate_synthetic_data(real_data, latent_dim, num_samples, save_dir):
    # Define input dimension
    input_dim = real_data.shape[1]

    # Instantiate VAE
    vae = VAE(latent_dim=latent_dim, input_dim=input_dim)
    vae.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3))

    # Train the VAE
    vae.fit(real_data, real_data, epochs=5, batch_size=32, verbose=1)

    # Generate synthetic data
    for i in range(100):  # Adjust the number of synthetic datasets if necessary
        z_samples = np.random.normal(size=(real_data.shape[0], latent_dim))
        synthetic_data = vae.decode(z_samples).numpy()

        # Save synthetic data
        np.save(os.path.join(save_dir, f"synthetic_data_{i+1}.npy"), synthetic_data)

        # Calculate and print similarity metrics
        mse = mean_squared_error(real_data, synthetic_data)
        cosine_sim = cosine_similarity(real_data.flatten().reshape(1, -1), synthetic_data.flatten().reshape(1, -1))[0][0]
        pearson_corr, _ = pearsonr(real_data.flatten(), synthetic_data.flatten())

        print(f"Metrics for synthetic data {i+1}:")
        print(f"  MSE: {mse}")
        print(f"  Cosine Similarity: {cosine_sim}")

        print(f"  Pearson Correlation: {pearson_corr}")
        print("-" * 50)

# Iterate over folders and generate synthetic data
latent_dim = 10
num_synthetic_samples = 150

for folder in folders:
    print(f"Processing folder: {folder}")

    folder_path = os.path.join(base_path, folder)
    save_dir = os.path.join(save_base_path, folder)
    os.makedirs(save_dir, exist_ok=True)

    # Load all .npy files in the folder
    file_paths = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if f.endswith(".npy")]
    real_data = np.vstack([np.load(file) for file in file_paths])

    # Generate and save synthetic data
    generate_synthetic_data(real_data, latent_dim, num_synthetic_samples, save_dir)
    print(f"Synthetic data generation for folder '{folder}' is complete!")
print("All synthetic data generation complete!")
# Out:
# Processing folder: Normal
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/5
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - kl_loss: 4.8431e-05 - loss: 0.0035 - reconstruction_loss: 0.0035
# Epoch 2/5
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - kl_loss: 3.4766e-06 - loss: 2.7994e-04 - reconstruction_loss: 2.7646e-04
# Epoch 3/5
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - kl_loss: 3.2462e-06 - loss: 2.7913e-04 - reconstruction_loss: 2.7588e-04
# Epoch 4/5
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - kl_loss: 3.5936e-06 - loss: 2.7936e-04 - reconstruction_loss: 2.7577e-04
# Epoch 5/5
# 1658/1658 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - kl_loss: 6.0251e-06 - loss: 2.8176e-04 - reconstruction_loss: 2.7573e-04
# Metrics for synthetic data 1:
#   MSE: 0.00027600726851156925
#   Cosine Similarity: 0.8746626396368249
#   Pearson Correlation: 0.6628395409112384
# --------------------------------------------------
# Metrics for synthetic data 2:
#   MSE: 0.00027601059500135725
#   Cosine Similarity: 0.7918045914293411
#   Pearson Correlation: 0.6278453900311587
# --------------------------------------------------
# Metrics for synthetic data 3:
#   MSE: 0.0002759993500113113
#   Cosine Similarity: 0.9262049451714597
#   Pearson Correlation: 0.6749184190804669
# --------------------------------------------------
# Metrics for synthetic data 4:
#   MSE: 0.00027600342604980344
#   Cosine Similarity: 0.9323804849133207
#   Pearson Correlation: 0.641852615087926
# --------------------------------------------------
# Metrics for synthetic data 5:
#   MSE: 0.0002760075965706479
#   Cosine Similarity: 0.8156458637162036
#   Pearson Correlation: 0.7088173585877087
# --------------------------------------------------
# Metrics for synthetic data 6:
#   MSE: 0.00027600675825065635
#   Cosine Similarity: 0.7738305296466056
#   Pearson Correlation: 0.6542265770875563
# --------------------------------------------------
# Metrics for synthetic data 7:
#   MSE: 0.0002759997219807595
#   Cosine Similarity: 0.9191447085067639
#   Pearson Correlation: 0.709808158745923
# --------------------------------------------------
# Metrics for synthetic data 8:
#   MSE: 0.0002760113289092908
#   Cosine Similarity: 0.8890529260743897
#   Pearson Correlation: 0.8940387591334039
# --------------------------------------------------
# Metrics for synthetic data 9:
#   MSE: 0.00027600575782538796
#   Cosine Similarity: 0.7606695515406499
#   Pearson Correlation: 0.7793607785563237
# --------------------------------------------------
# Metrics for synthetic data 10:
#   MSE: 0.0002760056543563467
#   Cosine Similarity: 0.8453661388993036
#   Pearson Correlation: 0.7487578524795436
# --------------------------------------------------
# Metrics for synthetic data 11:
#   MSE: 0.00027600495138619654
#   Cosine Similarity: 0.7833406637809278
#   Pearson Correlation: 0.6768209511758843
# --------------------------------------------------
# Metrics for synthetic data 12:
#   MSE: 0.00027600702577459116
#   Cosine Similarity: 0.7954577659911046
#   Pearson Correlation: 0.6530221911701933
# --------------------------------------------------
# Metrics for synthetic data 13:
#   MSE: 0.000276010000975106
#   Cosine Similarity: 0.7803022440787181
#   Pearson Correlation: 0.620771923548581
# --------------------------------------------------
# Metrics for synthetic data 14:
#   MSE: 0.00027600408627599096
#   Cosine Similarity: 0.8355360079623181
#   Pearson Correlation: 0.6714475855189089
# --------------------------------------------------
# Metrics for synthetic data 15:
#   MSE: 0.00027600617630362765
#   Cosine Similarity: 0.8523269189535538
#   Pearson Correlation: 0.6091395140450296
# --------------------------------------------------
# Metrics for synthetic data 16:
#   MSE: 0.00027601150839057454
#   Cosine Similarity: 0.7655860190300675
#   Pearson Correlation: 0.8940488542594855
# --------------------------------------------------
# Metrics for synthetic data 17:
#   MSE: 0.00027600506445921494
#   Cosine Similarity: 0.8410672022974112
#   Pearson Correlation: 0.7359509347710667
# --------------------------------------------------
# Metrics for synthetic data 18:
#   MSE: 0.0002760055407453722
#   Cosine Similarity: 0.9088803313995554
#   Pearson Correlation: 0.7281082118831621
# --------------------------------------------------
# Metrics for synthetic data 19:
#   MSE: 0.0002760058406744832
#   Cosine Similarity: 0.9464170410173949
#   Pearson Correlation: 0.7537363120915744
# --------------------------------------------------
# Metrics for synthetic data 20:
#   MSE: 0.0002760097795425948
#   Cosine Similarity: 0.7670461615475166
#   Pearson Correlation: 0.82724155224731
# --------------------------------------------------
# Metrics for synthetic data 21:
#   MSE: 0.0002760062412686779
#   Cosine Similarity: 0.7550104141233436
#   Pearson Correlation: 0.7333279799663863
# --------------------------------------------------
# Metrics for synthetic data 22:
#   MSE: 0.0002760022584158942
#   Cosine Similarity: 0.9011772918324316
#   Pearson Correlation: 0.8320339913980812
# --------------------------------------------------
# Metrics for synthetic data 23:
#   MSE: 0.0002759970714453569
#   Cosine Similarity: 0.7573577826275792
#   Pearson Correlation: 0.8729986240765946
# --------------------------------------------------
# Metrics for synthetic data 24:
#   MSE: 0.00027600843817552815
#   Cosine Similarity: 0.8689643659133401
#   Pearson Correlation: 0.7370368922490279
# --------------------------------------------------
# Metrics for synthetic data 25:
#   MSE: 0.00027600022067492184
#   Cosine Similarity: 0.8432680680061067
#   Pearson Correlation: 0.6556495340100228
# --------------------------------------------------
# Metrics for synthetic data 26:
#   MSE: 0.00027600956519793296
#   Cosine Similarity: 0.8307497959278488
#   Pearson Correlation: 0.6174045363285755
# --------------------------------------------------
# Metrics for synthetic data 27:
#   MSE: 0.00027600556296519146
#   Cosine Similarity: 0.8706237651766116
#   Pearson Correlation: 0.6725567290912938
# --------------------------------------------------
# Metrics for synthetic data 28:
#   MSE: 0.00027600590573773195
#   Cosine Similarity: 0.8334844734330257
#   Pearson Correlation: 0.8959928342760464
# --------------------------------------------------
# Metrics for synthetic data 29:
#   MSE: 0.00027600627759958603
#   Cosine Similarity: 0.7576186370992194
#   Pearson Correlation: 0.7152805481788033
# --------------------------------------------------
# Metrics for synthetic data 30:
#   MSE: 0.00027601013185759915
#   Cosine Similarity: 0.8503632551901046
#   Pearson Correlation: 0.8036108829285697
# --------------------------------------------------
# Metrics for synthetic data 31:
#   MSE: 0.0002759937209553754
#   Cosine Similarity: 0.8758645102828145
#   Pearson Correlation: 0.8175993513904299
# --------------------------------------------------
# Metrics for synthetic data 32:
#   MSE: 0.00027600346647293063
#   Cosine Similarity: 0.8311228742893567
#   Pearson Correlation: 0.7286407587070691
# --------------------------------------------------
# Metrics for synthetic data 33:
#   MSE: 0.0002760062138726078
#   Cosine Similarity: 0.7644202528780015
#   Pearson Correlation: 0.8311553775284131
# --------------------------------------------------
# Metrics for synthetic data 34:
#   MSE: 0.0002760089507556083
#   Cosine Similarity: 0.9150759476780688
#   Pearson Correlation: 0.7534549442345769
# --------------------------------------------------
# Metrics for synthetic data 35:
#   MSE: 0.00027600575928507666
#   Cosine Similarity: 0.8046739161476527
#   Pearson Correlation: 0.7322053225068591
# --------------------------------------------------
# Metrics for synthetic data 36:
#   MSE: 0.0002760051899527171
#   Cosine Similarity: 0.7646795709796806
#   Pearson Correlation: 0.7313236605421493
# --------------------------------------------------
# Metrics for synthetic data 37:
#   MSE: 0.00027601635644612226
#   Cosine Similarity: 0.8874339693059885
#   Pearson Correlation: 0.7796498868535587
# --------------------------------------------------
# Metrics for synthetic data 38:
#   MSE: 0.0002760027411514788
#   Cosine Similarity: 0.9301926780264224
#   Pearson Correlation: 0.6528918274827872
# --------------------------------------------------
# Metrics for synthetic data 39:
#   MSE: 0.00027601072376471427
#   Cosine Similarity: 0.9240378553282529
#   Pearson Correlation: 0.6762749093202746
# --------------------------------------------------
# Metrics for synthetic data 40:
#   MSE: 0.0002760046960887015
#   Cosine Similarity: 0.8461804259679989
#   Pearson Correlation: 0.809692979693162
# --------------------------------------------------
# Metrics for synthetic data 41:
#   MSE: 0.0002760071390858959
#   Cosine Similarity: 0.8543454350604124
#   Pearson Correlation: 0.6901650848107637
# --------------------------------------------------
# Metrics for synthetic data 42:
#   MSE: 0.000276001127860647
#   Cosine Similarity: 0.8593070612024198
#   Pearson Correlation: 0.723548371878283
# --------------------------------------------------
# Metrics for synthetic data 43:
#   MSE: 0.00027600690672359933
#   Cosine Similarity: 0.7981793772734871
#   Pearson Correlation: 0.885379076583595
# --------------------------------------------------
# Metrics for synthetic data 44:
#   MSE: 0.0002760079501129877
#   Cosine Similarity: 0.923828855639309
#   Pearson Correlation: 0.6901621803990637
# --------------------------------------------------
# Metrics for synthetic data 45:
#   MSE: 0.00027600562506750124
#   Cosine Similarity: 0.8242654240917809
#   Pearson Correlation: 0.8573412626364342
# --------------------------------------------------
# Metrics for synthetic data 46:
#   MSE: 0.0002760044761755787
#   Cosine Similarity: 0.7591492518296735
#   Pearson Correlation: 0.7348483285734042
# --------------------------------------------------
# Metrics for synthetic data 47:
#   MSE: 0.0002760066817019882
#   Cosine Similarity: 0.8669899345763654
#   Pearson Correlation: 0.8180285985549738
# --------------------------------------------------
# Metrics for synthetic data 48:
#   MSE: 0.00027599807325647143
#   Cosine Similarity: 0.910746384416675
#   Pearson Correlation: 0.8321351301266675
# --------------------------------------------------
# Metrics for synthetic data 49:
#   MSE: 0.00027600562533104244
#   Cosine Similarity: 0.7881422380309033
#   Pearson Correlation: 0.6465185953018611
# --------------------------------------------------
# Metrics for synthetic data 50:
#   MSE: 0.00027600428415608093
#   Cosine Similarity: 0.80731659512758
#   Pearson Correlation: 0.8187740728852396
# --------------------------------------------------
# Metrics for synthetic data 51:
#   MSE: 0.0002760030344287736
#   Cosine Similarity: 0.9356614242758589
#   Pearson Correlation: 0.8112727280322956
# --------------------------------------------------
# Metrics for synthetic data 52:
#   MSE: 0.00027600822073959176
#   Cosine Similarity: 0.9268783550041967
#   Pearson Correlation: 0.8706195375411805
# --------------------------------------------------
# Metrics for synthetic data 53:
#   MSE: 0.0002760080768047929
#   Cosine Similarity: 0.828821223233053
#   Pearson Correlation: 0.801129351493934
# --------------------------------------------------
# Metrics for synthetic data 54:
#   MSE: 0.000276007964036586
#   Cosine Similarity: 0.7550555400395094
#   Pearson Correlation: 0.6032852238134059
# --------------------------------------------------
# Metrics for synthetic data 55:
#   MSE: 0.00027601409395807265
#   Cosine Similarity: 0.7670547732362047
#   Pearson Correlation: 0.685687092386863
# --------------------------------------------------
# Metrics for synthetic data 56:
#   MSE: 0.0002760039346328048
#   Cosine Similarity: 0.8375135841468364
#   Pearson Correlation: 0.7243380275877964
# --------------------------------------------------
# Metrics for synthetic data 57:
#   MSE: 0.00027600076123535225
#   Cosine Similarity: 0.7803120840501495
#   Pearson Correlation: 0.6945641498850031
# --------------------------------------------------
# Metrics for synthetic data 58:
#   MSE: 0.00027600836690559516
#   Cosine Similarity: 0.9040006925951094
#   Pearson Correlation: 0.8039015741791954
# --------------------------------------------------
# Metrics for synthetic data 59:
#   MSE: 0.00027600986961950636
#   Cosine Similarity: 0.8665451167397089
#   Pearson Correlation: 0.6832765084114102
# --------------------------------------------------
# Metrics for synthetic data 60:
#   MSE: 0.0002760023183099622
#   Cosine Similarity: 0.8533850166575205
#   Pearson Correlation: 0.7025003567716346
# --------------------------------------------------
# Metrics for synthetic data 61:
#   MSE: 0.0002760129675904659
#   Cosine Similarity: 0.8922740328132991
#   Pearson Correlation: 0.8939954003023561
# --------------------------------------------------
# Metrics for synthetic data 62:
#   MSE: 0.00027600501877324285
#   Cosine Similarity: 0.8529320069885421
#   Pearson Correlation: 0.6741056212506737
# --------------------------------------------------
# Metrics for synthetic data 63:
#   MSE: 0.0002760112544335405
#   Cosine Similarity: 0.8165013391723795
#   Pearson Correlation: 0.781097216213162
# --------------------------------------------------
# Metrics for synthetic data 64:
#   MSE: 0.0002760063019077752
#   Cosine Similarity: 0.9030277409288385
#   Pearson Correlation: 0.8593542922003143
# --------------------------------------------------
# Metrics for synthetic data 65:
#   MSE: 0.00027600602104773075
#   Cosine Similarity: 0.8786500500115726
#   Pearson Correlation: 0.7442654579751319
# --------------------------------------------------
# Metrics for synthetic data 66:
#   MSE: 0.00027600494787065246
#   Cosine Similarity: 0.7902755921982726
#   Pearson Correlation: 0.768284776707651
# --------------------------------------------------
# Metrics for synthetic data 67:
#   MSE: 0.0002759993084496021
#   Cosine Similarity: 0.9158347453105853
#   Pearson Correlation: 0.6873359819109293
# --------------------------------------------------
# Metrics for synthetic data 68:
#   MSE: 0.00027600820056071675
#   Cosine Similarity: 0.920369116288717
#   Pearson Correlation: 0.8737654199696864
# --------------------------------------------------
# Metrics for synthetic data 69:
#   MSE: 0.0002760156514294845
#   Cosine Similarity: 0.7685711992008754
#   Pearson Correlation: 0.8628595452185857
# --------------------------------------------------
# Metrics for synthetic data 70:
#   MSE: 0.0002760152709642486
#   Cosine Similarity: 0.9163291822339511
#   Pearson Correlation: 0.8271622522415665
# --------------------------------------------------
# Metrics for synthetic data 71:
#   MSE: 0.00027601092654382743
#   Cosine Similarity: 0.8063903593425238
#   Pearson Correlation: 0.7438521571039584
# --------------------------------------------------
# Metrics for synthetic data 72:
#   MSE: 0.0002760061106684311
#   Cosine Similarity: 0.8608730757426343
#   Pearson Correlation: 0.8274806274114801
# --------------------------------------------------
# Metrics for synthetic data 73:
#   MSE: 0.0002759975637010327
#   Cosine Similarity: 0.855319745821989
#   Pearson Correlation: 0.734567369941768
# --------------------------------------------------
# Metrics for synthetic data 74:
#   MSE: 0.0002760045777304223
#   Cosine Similarity: 0.8107868074517448
#   Pearson Correlation: 0.7326034671376123
# --------------------------------------------------
# Metrics for synthetic data 75:
#   MSE: 0.00027600907993260927
#   Cosine Similarity: 0.8379098216053847
#   Pearson Correlation: 0.8671873511034256
# --------------------------------------------------
# Metrics for synthetic data 76:
#   MSE: 0.0002760048308839443
#   Cosine Similarity: 0.8659954580946309
#   Pearson Correlation: 0.6317952408992914
# --------------------------------------------------
# Metrics for synthetic data 77:
#   MSE: 0.0002760064872430756
#   Cosine Similarity: 0.8423181401761349
#   Pearson Correlation: 0.6115040588536097
# --------------------------------------------------
# Metrics for synthetic data 78:
#   MSE: 0.00027600697071173514
#   Cosine Similarity: 0.8792792894401193
#   Pearson Correlation: 0.7100215256270478
# --------------------------------------------------
# Metrics for synthetic data 79:
#   MSE: 0.0002760078884585481
#   Cosine Similarity: 0.8468909652712778
#   Pearson Correlation: 0.7275536019008417
# --------------------------------------------------
# Metrics for synthetic data 80:
#   MSE: 0.0002760044831560089
#   Cosine Similarity: 0.8239855784525871
#   Pearson Correlation: 0.7384431036858741
# --------------------------------------------------
# Metrics for synthetic data 81:
#   MSE: 0.0002760016701713789
#   Cosine Similarity: 0.8532591291869724
#   Pearson Correlation: 0.8849287582339058
# --------------------------------------------------
# Metrics for synthetic data 82:
#   MSE: 0.00027600178500435406
#   Cosine Similarity: 0.9020493618941616
#   Pearson Correlation: 0.8332335378455317
# --------------------------------------------------
# Metrics for synthetic data 83:
#   MSE: 0.0002759999619519794
#   Cosine Similarity: 0.846591492825559
#   Pearson Correlation: 0.8369680089546871
# --------------------------------------------------
# Metrics for synthetic data 84:
#   MSE: 0.00027600475762437984
#   Cosine Similarity: 0.8552740413596541
#   Pearson Correlation: 0.7012599296206722
# --------------------------------------------------
# Metrics for synthetic data 85:
#   MSE: 0.00027600626151432986
#   Cosine Similarity: 0.8665741707908677
#   Pearson Correlation: 0.6806065525851792
# --------------------------------------------------
# Metrics for synthetic data 86:
#   MSE: 0.00027601002389464585
#   Cosine Similarity: 0.8383214765117158
#   Pearson Correlation: 0.6679023125826933
# --------------------------------------------------
# Metrics for synthetic data 87:
#   MSE: 0.0002760025914911679
#   Cosine Similarity: 0.7755696321660913
#   Pearson Correlation: 0.7305534038379672
# --------------------------------------------------
# Metrics for synthetic data 88:
#   MSE: 0.0002759978314911079
#   Cosine Similarity: 0.900728079869779
#   Pearson Correlation: 0.7025088418968564
# --------------------------------------------------
# Metrics for synthetic data 89:
#   MSE: 0.0002760022539527854
#   Cosine Similarity: 0.8613456765814432
#   Pearson Correlation: 0.8883582307746448
# --------------------------------------------------
# Metrics for synthetic data 90:
#   MSE: 0.0002759968218590238
#   Cosine Similarity: 0.8963464687700532
#   Pearson Correlation: 0.8619406422190081
# --------------------------------------------------
# Metrics for synthetic data 91:
#   MSE: 0.0002760074364926431
#   Cosine Similarity: 0.7724049642360585
#   Pearson Correlation: 0.6670111649454216
# --------------------------------------------------
# Metrics for synthetic data 92:
#   MSE: 0.0002760027927686165
#   Cosine Similarity: 0.7766849094219229
#   Pearson Correlation: 0.8870882694678308
# --------------------------------------------------
# Metrics for synthetic data 93:
#   MSE: 0.000276008483852671
#   Cosine Similarity: 0.9297286817458067
#   Pearson Correlation: 0.6028820269351625
# --------------------------------------------------
# Metrics for synthetic data 94:
#   MSE: 0.00027600847071137857
#   Cosine Similarity: 0.7962284024028745
#   Pearson Correlation: 0.741519627197704
# --------------------------------------------------
# Metrics for synthetic data 95:
#   MSE: 0.00027600912541075277
#   Cosine Similarity: 0.9151078331563107
#   Pearson Correlation: 0.8224491329386368
# --------------------------------------------------
# Metrics for synthetic data 96:
#   MSE: 0.00027600481750927604
#   Cosine Similarity: 0.7606789964027126
#   Pearson Correlation: 0.8869514861672096
# --------------------------------------------------
# Metrics for synthetic data 97:
#   MSE: 0.00027600743397817896
#   Cosine Similarity: 0.866215366549062
#   Pearson Correlation: 0.8923112513755944
# --------------------------------------------------
# Metrics for synthetic data 98:
#   MSE: 0.0002760010462342031
#   Cosine Similarity: 0.9290321353865475
#   Pearson Correlation: 0.6861008506959925
# --------------------------------------------------
# Metrics for synthetic data 99:
#   MSE: 0.0002760040563239691
#   Cosine Similarity: 0.895361525314959
#   Pearson Correlation: 0.7447265596373127
# --------------------------------------------------
# Metrics for synthetic data 100:
#   MSE: 0.00027600906295797804
#   Cosine Similarity: 0.9395312770328902
#   Pearson Correlation: 0.6774803686730417
# --------------------------------------------------
# Synthetic data generation for folder 'Normal' is complete!
# Processing folder: Video_detected_Seizures_with_no_visual_change_over_EEG
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - kl_loss: 0.0014 - loss: 0.0995 - reconstruction_loss: 0.0981
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - kl_loss: 0.0014 - loss: 0.0027 - reconstruction_loss: 0.0013
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - kl_loss: 4.9970e-04 - loss: 0.0014 - reconstruction_loss: 9.4566e-04
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - kl_loss: 2.4216e-04 - loss: 0.0011 - reconstruction_loss: 8.3032e-04
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - kl_loss: 2.5901e-04 - loss: 0.0010 - reconstruction_loss: 7.7706e-04
# Metrics for synthetic data 1:
#   MSE: 0.0007705991687696336
#   Cosine Similarity: 0.7562694930108546
#   Pearson Correlation: 0.6294683474810847
# --------------------------------------------------
# Metrics for synthetic data 2:
#   MSE: 0.000774323176165591
#   Cosine Similarity: 0.8989617459909158
#   Pearson Correlation: 0.7244030881800813
# --------------------------------------------------
# Metrics for synthetic data 3:
#   MSE: 0.0007774203156275557
#   Cosine Similarity: 0.8454767907556394
#   Pearson Correlation: 0.6667077782863595
# --------------------------------------------------
# Metrics for synthetic data 4:
#   MSE: 0.0007774096814560853
#   Cosine Similarity: 0.8300247937690106
#   Pearson Correlation: 0.7619899726274341
# --------------------------------------------------
# Metrics for synthetic data 5:
#   MSE: 0.0007710682213237292
#   Cosine Similarity: 0.8405497461932506
#   Pearson Correlation: 0.8391236871565537
# --------------------------------------------------
# Metrics for synthetic data 6:
#   MSE: 0.0007774034814628394
#   Cosine Similarity: 0.9107394563074592
#   Pearson Correlation: 0.7319637185628984
# --------------------------------------------------
# Metrics for synthetic data 7:
#   MSE: 0.0007735824714273764
#   Cosine Similarity: 0.799918145833708
#   Pearson Correlation: 0.7882387341266262
# --------------------------------------------------
# Metrics for synthetic data 8:
#   MSE: 0.000777936713296425
#   Cosine Similarity: 0.7968704147198824
#   Pearson Correlation: 0.7687378289937222
# --------------------------------------------------
# Metrics for synthetic data 9:
#   MSE: 0.0007874146006223816
#   Cosine Similarity: 0.9287223606452835
#   Pearson Correlation: 0.7763404435157245
# --------------------------------------------------
# Metrics for synthetic data 10:
#   MSE: 0.0007690790188079428
#   Cosine Similarity: 0.8211810698301576
#   Pearson Correlation: 0.6079137607561054
# --------------------------------------------------
# Metrics for synthetic data 11:
#   MSE: 0.0007695524094217201
#   Cosine Similarity: 0.8327727475592279
#   Pearson Correlation: 0.8700698813650994
# --------------------------------------------------
# Metrics for synthetic data 12:
#   MSE: 0.0007581111128048332
#   Cosine Similarity: 0.7714215167388361
#   Pearson Correlation: 0.7159694327810506
# --------------------------------------------------
# Metrics for synthetic data 13:
#   MSE: 0.0007704777921626185
#   Cosine Similarity: 0.8642260483633784
#   Pearson Correlation: 0.6633003131945177
# --------------------------------------------------
# Metrics for synthetic data 14:
#   MSE: 0.0007854356848426975
#   Cosine Similarity: 0.7524401004515526
#   Pearson Correlation: 0.8037694682433238
# --------------------------------------------------
# Metrics for synthetic data 15:
#   MSE: 0.0007828777233156265
#   Cosine Similarity: 0.8456587921069035
#   Pearson Correlation: 0.7099335954591344
# --------------------------------------------------
# Metrics for synthetic data 16:
#   MSE: 0.0007643875591310773
#   Cosine Similarity: 0.7704555959049788
#   Pearson Correlation: 0.7072126729578441
# --------------------------------------------------
# Metrics for synthetic data 17:
#   MSE: 0.0007684272817872954
#   Cosine Similarity: 0.9306110558534181
#   Pearson Correlation: 0.8911250498483129
# --------------------------------------------------
# Metrics for synthetic data 18:
#   MSE: 0.0007715537119738343
#   Cosine Similarity: 0.8523108247635874
#   Pearson Correlation: 0.6193661517719179
# --------------------------------------------------
# Metrics for synthetic data 19:
#   MSE: 0.0007653000256056101
#   Cosine Similarity: 0.8759293641548365
#   Pearson Correlation: 0.6898703765059006
# --------------------------------------------------
# Metrics for synthetic data 20:
#   MSE: 0.0007687364678975901
#   Cosine Similarity: 0.8322141013316325
#   Pearson Correlation: 0.8201938148498642
# --------------------------------------------------
# Metrics for synthetic data 21:
#   MSE: 0.0007874668737295456
#   Cosine Similarity: 0.8269735900519511
#   Pearson Correlation: 0.7342861175841219
# --------------------------------------------------
# Metrics for synthetic data 22:
#   MSE: 0.0007706965664475907
#   Cosine Similarity: 0.8766535715112114
#   Pearson Correlation: 0.866397562310212
# --------------------------------------------------
# Metrics for synthetic data 23:
#   MSE: 0.0007702011866652753
#   Cosine Similarity: 0.8716243639495758
#   Pearson Correlation: 0.8319118316611326
# --------------------------------------------------
# Metrics for synthetic data 24:
#   MSE: 0.0007652616647031368
#   Cosine Similarity: 0.7741271640301316
#   Pearson Correlation: 0.7135761921806089
# --------------------------------------------------
# Metrics for synthetic data 25:
#   MSE: 0.0007830116537740888
#   Cosine Similarity: 0.8680177497243697
#   Pearson Correlation: 0.7215652261641359
# --------------------------------------------------
# Metrics for synthetic data 26:
#   MSE: 0.0007851251695620991
#   Cosine Similarity: 0.9486839049904698
#   Pearson Correlation: 0.763563171864692
# --------------------------------------------------
# Metrics for synthetic data 27:
#   MSE: 0.0007641811787628634
#   Cosine Similarity: 0.8312979516113747
#   Pearson Correlation: 0.865308076514387
# --------------------------------------------------
# Metrics for synthetic data 28:
#   MSE: 0.0007681972568626958
#   Cosine Similarity: 0.8217283599500055
#   Pearson Correlation: 0.7913424706571979
# --------------------------------------------------
# Metrics for synthetic data 29:
#   MSE: 0.0007668862179421168
#   Cosine Similarity: 0.8237607303753479
#   Pearson Correlation: 0.6800438361935668
# --------------------------------------------------
# Metrics for synthetic data 30:
#   MSE: 0.0007761060661749113
#   Cosine Similarity: 0.9448181453726265
#   Pearson Correlation: 0.85769383815221
# --------------------------------------------------
# Metrics for synthetic data 31:
#   MSE: 0.000772673700190841
#   Cosine Similarity: 0.8406556553755029
#   Pearson Correlation: 0.6674765872730967
# --------------------------------------------------
# Metrics for synthetic data 32:
#   MSE: 0.0007729818967680311
#   Cosine Similarity: 0.832008913727541
#   Pearson Correlation: 0.6444394374191686
# --------------------------------------------------
# Metrics for synthetic data 33:
#   MSE: 0.0007751586205423465
#   Cosine Similarity: 0.9002516282637206
#   Pearson Correlation: 0.7240057856716079
# --------------------------------------------------
# Metrics for synthetic data 34:
#   MSE: 0.0007740708701086617
#   Cosine Similarity: 0.8668663263731136
#   Pearson Correlation: 0.6160175325726823
# --------------------------------------------------
# Metrics for synthetic data 35:
#   MSE: 0.0007712456592152391
#   Cosine Similarity: 0.9003329042228132
#   Pearson Correlation: 0.7138976365533003
# --------------------------------------------------
# Metrics for synthetic data 36:
#   MSE: 0.0007815270986478091
#   Cosine Similarity: 0.9213829020101317
#   Pearson Correlation: 0.7925260327404882
# --------------------------------------------------
# Metrics for synthetic data 37:
#   MSE: 0.0007655950408991439
#   Cosine Similarity: 0.788574326151495
#   Pearson Correlation: 0.815631740459186
# --------------------------------------------------
# Metrics for synthetic data 38:
#   MSE: 0.0007807181582918003
#   Cosine Similarity: 0.751619935587952
#   Pearson Correlation: 0.8877674526955677
# --------------------------------------------------
# Metrics for synthetic data 39:
#   MSE: 0.0007656896683911715
#   Cosine Similarity: 0.7832363122857339
#   Pearson Correlation: 0.6311376561868552
# --------------------------------------------------
# Metrics for synthetic data 40:
#   MSE: 0.000777498861945521
#   Cosine Similarity: 0.8221912240330314
#   Pearson Correlation: 0.7061470559898294
# --------------------------------------------------
# Metrics for synthetic data 41:
#   MSE: 0.0007715161835405241
#   Cosine Similarity: 0.8215204039427946
#   Pearson Correlation: 0.7839834000594796
# --------------------------------------------------
# Metrics for synthetic data 42:
#   MSE: 0.0007806034239963651
#   Cosine Similarity: 0.755776484521775
#   Pearson Correlation: 0.892785846260437
# --------------------------------------------------
# Metrics for synthetic data 43:
#   MSE: 0.0007676683209616752
#   Cosine Similarity: 0.854383423607671
#   Pearson Correlation: 0.62235993223699
# --------------------------------------------------
# Metrics for synthetic data 44:
#   MSE: 0.00076423741581005
#   Cosine Similarity: 0.8248883397421026
#   Pearson Correlation: 0.8212821888098819
# --------------------------------------------------
# Metrics for synthetic data 45:
#   MSE: 0.0007660608287323697
#   Cosine Similarity: 0.8228772646739038
#   Pearson Correlation: 0.6295417642265266
# --------------------------------------------------
# Metrics for synthetic data 46:
#   MSE: 0.0007710554675316033
#   Cosine Similarity: 0.8266984181948365
#   Pearson Correlation: 0.7625346174723562
# --------------------------------------------------
# Metrics for synthetic data 47:
#   MSE: 0.0007844463758151912
#   Cosine Similarity: 0.7754819176170686
#   Pearson Correlation: 0.846023338322305
# --------------------------------------------------
# Metrics for synthetic data 48:
#   MSE: 0.0007785682215144089
#   Cosine Similarity: 0.8178581171655405
#   Pearson Correlation: 0.8017662077352512
# --------------------------------------------------
# Metrics for synthetic data 49:
#   MSE: 0.0007745365733349662
#   Cosine Similarity: 0.9387539969411913
#   Pearson Correlation: 0.6601678810290585
# --------------------------------------------------
# Metrics for synthetic data 50:
#   MSE: 0.0007849376971525184
#   Cosine Similarity: 0.7696923095536263
#   Pearson Correlation: 0.7744113078832076
# --------------------------------------------------
# Metrics for synthetic data 51:
#   MSE: 0.0007831011862587804
#   Cosine Similarity: 0.8037425029585717
#   Pearson Correlation: 0.6009663966027368
# --------------------------------------------------
# Metrics for synthetic data 52:
#   MSE: 0.000778241679090061
#   Cosine Similarity: 0.876498785845059
#   Pearson Correlation: 0.7293155954762517
# --------------------------------------------------
# Metrics for synthetic data 53:
#   MSE: 0.0007763167994319005
#   Cosine Similarity: 0.8928316896322757
#   Pearson Correlation: 0.7559883683297896
# --------------------------------------------------
# Metrics for synthetic data 54:
#   MSE: 0.0007632017934115563
#   Cosine Similarity: 0.7936758764576349
#   Pearson Correlation: 0.79123733790507
# --------------------------------------------------
# Metrics for synthetic data 55:
#   MSE: 0.0007710488311257953
#   Cosine Similarity: 0.9132155147752294
#   Pearson Correlation: 0.6348750107610153
# --------------------------------------------------
# Metrics for synthetic data 56:
#   MSE: 0.0007718739331966398
#   Cosine Similarity: 0.7983537288318301
#   Pearson Correlation: 0.7308673332228197
# --------------------------------------------------
# Metrics for synthetic data 57:
#   MSE: 0.000766582881609826
#   Cosine Similarity: 0.9049257827947623
#   Pearson Correlation: 0.6451689267066719
# --------------------------------------------------
# Metrics for synthetic data 58:
#   MSE: 0.000772073980995584
#   Cosine Similarity: 0.8233078850400719
#   Pearson Correlation: 0.6784457257825962
# --------------------------------------------------
# Metrics for synthetic data 59:
#   MSE: 0.0007657519181919932
#   Cosine Similarity: 0.9126797064664809
#   Pearson Correlation: 0.6188389898453402
# --------------------------------------------------
# Metrics for synthetic data 60:
#   MSE: 0.0007812199722113753
#   Cosine Similarity: 0.8981716750147148
#   Pearson Correlation: 0.623260941237745
# --------------------------------------------------
# Metrics for synthetic data 61:
#   MSE: 0.0007671784133484583
#   Cosine Similarity: 0.789819718248542
#   Pearson Correlation: 0.8019080903119634
# --------------------------------------------------
# Metrics for synthetic data 62:
#   MSE: 0.0007676764935972602
#   Cosine Similarity: 0.8228957440089726
#   Pearson Correlation: 0.6512117024294664
# --------------------------------------------------
# Metrics for synthetic data 63:
#   MSE: 0.0007618625089850273
#   Cosine Similarity: 0.7806186515177014
#   Pearson Correlation: 0.8935388789465663
# --------------------------------------------------
# Metrics for synthetic data 64:
#   MSE: 0.0007679311974477433
#   Cosine Similarity: 0.8682632132947178
#   Pearson Correlation: 0.8655063742308663
# --------------------------------------------------
# Metrics for synthetic data 65:
#   MSE: 0.0007762945180386688
#   Cosine Similarity: 0.7589721877155954
#   Pearson Correlation: 0.7928764053127778
# --------------------------------------------------
# Metrics for synthetic data 66:
#   MSE: 0.0007831592258934206
#   Cosine Similarity: 0.8445664437330241
#   Pearson Correlation: 0.8040930972387252
# --------------------------------------------------
# Metrics for synthetic data 67:
#   MSE: 0.0007831721851819316
#   Cosine Similarity: 0.8462606737658928
#   Pearson Correlation: 0.6604170522262727
# --------------------------------------------------
# Metrics for synthetic data 68:
#   MSE: 0.0007714256407366879
#   Cosine Similarity: 0.9363709345450351
#   Pearson Correlation: 0.7166695458427013
# --------------------------------------------------
# Metrics for synthetic data 69:
#   MSE: 0.0007749031746981332
#   Cosine Similarity: 0.8842966277905635
#   Pearson Correlation: 0.8226054124536479
# --------------------------------------------------
# Metrics for synthetic data 70:
#   MSE: 0.0007733643546702551
#   Cosine Similarity: 0.8382169741793105
#   Pearson Correlation: 0.771471427200512
# --------------------------------------------------
# Metrics for synthetic data 71:
#   MSE: 0.0007694274631998183
#   Cosine Similarity: 0.893248401961677
#   Pearson Correlation: 0.8353374814823413
# --------------------------------------------------
# Metrics for synthetic data 72:
#   MSE: 0.000783518523708338
#   Cosine Similarity: 0.9089983290364816
#   Pearson Correlation: 0.6282241446606157
# --------------------------------------------------
# Metrics for synthetic data 73:
#   MSE: 0.0007832988467156679
#   Cosine Similarity: 0.9417491112537713
#   Pearson Correlation: 0.8602626799769051
# --------------------------------------------------
# Metrics for synthetic data 74:
#   MSE: 0.000779395125162613
#   Cosine Similarity: 0.9351400703892112
#   Pearson Correlation: 0.8615207368719408
# --------------------------------------------------
# Metrics for synthetic data 75:
#   MSE: 0.0007766020542187273
#   Cosine Similarity: 0.8735708358060634
#   Pearson Correlation: 0.731535132809231
# --------------------------------------------------
# Metrics for synthetic data 76:
#   MSE: 0.000774415771447333
#   Cosine Similarity: 0.9126100388153264
#   Pearson Correlation: 0.831799087200417
# --------------------------------------------------
# Metrics for synthetic data 77:
#   MSE: 0.0007736601182149733
#   Cosine Similarity: 0.8194153755279299
#   Pearson Correlation: 0.8419857884827919
# --------------------------------------------------
# Metrics for synthetic data 78:
#   MSE: 0.0007707663020142727
#   Cosine Similarity: 0.7858547551248309
#   Pearson Correlation: 0.6439414899589219
# --------------------------------------------------
# Metrics for synthetic data 79:
#   MSE: 0.0007770076483292778
#   Cosine Similarity: 0.8450421339274982
#   Pearson Correlation: 0.7611669827700318
# --------------------------------------------------
# Metrics for synthetic data 80:
#   MSE: 0.0007681823654122803
#   Cosine Similarity: 0.8512769958194611
#   Pearson Correlation: 0.8857854606079195
# --------------------------------------------------
# Metrics for synthetic data 81:
#   MSE: 0.0007728068514547057
#   Cosine Similarity: 0.8667083071756441
#   Pearson Correlation: 0.7977498278163465
# --------------------------------------------------
# Metrics for synthetic data 82:
#   MSE: 0.000792462330643727
#   Cosine Similarity: 0.8951973308241573
#   Pearson Correlation: 0.6971092243923177
# --------------------------------------------------
# Metrics for synthetic data 83:
#   MSE: 0.0007840709090759925
#   Cosine Similarity: 0.7510869242588905
#   Pearson Correlation: 0.7528804291909343
# --------------------------------------------------
# Metrics for synthetic data 84:
#   MSE: 0.00077493514086808
#   Cosine Similarity: 0.7655460484621265
#   Pearson Correlation: 0.86858959691605
# --------------------------------------------------
# Metrics for synthetic data 85:
#   MSE: 0.0007799559847518733
#   Cosine Similarity: 0.9034558577950471
#   Pearson Correlation: 0.7747573448735053
# --------------------------------------------------
# Metrics for synthetic data 86:
#   MSE: 0.0007694158248565842
#   Cosine Similarity: 0.9279541821086943
#   Pearson Correlation: 0.733726470496529
# --------------------------------------------------
# Metrics for synthetic data 87:
#   MSE: 0.0007714133925375277
#   Cosine Similarity: 0.7613575340408636
#   Pearson Correlation: 0.8253136785329844
# --------------------------------------------------
# Metrics for synthetic data 88:
#   MSE: 0.0007690082428644616
#   Cosine Similarity: 0.8106206654150939
#   Pearson Correlation: 0.8704399151260022
# --------------------------------------------------
# Metrics for synthetic data 89:
#   MSE: 0.0007690632074301975
#   Cosine Similarity: 0.8374590889803267
#   Pearson Correlation: 0.8406363483073649
# --------------------------------------------------
# Metrics for synthetic data 90:
#   MSE: 0.0007623259100680189
#   Cosine Similarity: 0.8471040534142932
#   Pearson Correlation: 0.6878124827565676
# --------------------------------------------------
# Metrics for synthetic data 91:
#   MSE: 0.0007748032463267769
#   Cosine Similarity: 0.8516195096909682
#   Pearson Correlation: 0.7620051783830757
# --------------------------------------------------
# Metrics for synthetic data 92:
#   MSE: 0.0007716171138817579
#   Cosine Similarity: 0.7768513023599848
#   Pearson Correlation: 0.825919796321637
# --------------------------------------------------
# Metrics for synthetic data 93:
#   MSE: 0.0007782304628272274
#   Cosine Similarity: 0.7959274262489215
#   Pearson Correlation: 0.6174277897585163
# --------------------------------------------------
# Metrics for synthetic data 94:
#   MSE: 0.0007839798173061338
#   Cosine Similarity: 0.8279045903633319
#   Pearson Correlation: 0.7559467539834825
# --------------------------------------------------
# Metrics for synthetic data 95:
#   MSE: 0.0007676371366354018
#   Cosine Similarity: 0.8989192072433244
#   Pearson Correlation: 0.6359068895251536
# --------------------------------------------------
# Metrics for synthetic data 96:
#   MSE: 0.0007778736469300434
#   Cosine Similarity: 0.887731899369301
#   Pearson Correlation: 0.602573087770132
# --------------------------------------------------
# Metrics for synthetic data 97:
#   MSE: 0.0007704041361388998
#   Cosine Similarity: 0.8179300917840545
#   Pearson Correlation: 0.6384552461343035
# --------------------------------------------------
# Metrics for synthetic data 98:
#   MSE: 0.0007710069218477804
#   Cosine Similarity: 0.9208350523304244
#   Pearson Correlation: 0.6243790312374105
# --------------------------------------------------
# Metrics for synthetic data 99:
#   MSE: 0.0007708980350557014
#   Cosine Similarity: 0.857569459699137
#   Pearson Correlation: 0.7805398001333339
# --------------------------------------------------
# Metrics for synthetic data 100:
#   MSE: 0.0007732288232429064
#   Cosine Similarity: 0.8109620078104256
#   Pearson Correlation: 0.8822540058397015
# --------------------------------------------------
# Synthetic data generation for folder 'Video_detected_Seizures_with_no_visual_change_over_EEG' is complete!
# Processing folder: Complex_Partial_Seizures
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/input_layer.py:26: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Epoch 1/5
# 1304/1304 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - kl_loss: 1.4898e-04 - loss: 0.0049 - reconstruction_loss: 0.0047
# Epoch 2/5
# 1304/1304 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - kl_loss: 1.1272e-06 - loss: 0.0010 - reconstruction_loss: 0.0010
# Epoch 3/5
# 1304/1304 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - kl_loss: 1.7950e-06 - loss: 0.0010 - reconstruction_loss: 0.0010
# Epoch 4/5
# 1304/1304 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - kl_loss: 6.0711e-06 - loss: 0.0010 - reconstruction_loss: 0.0010
# Epoch 5/5
# 1304/1304 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - kl_loss: 4.4949e-07 - loss: 0.0010 - reconstruction_loss: 0.0010
# Metrics for synthetic data 1:
#   MSE: 0.0010271700083456022
#   Cosine Similarity: 0.9065002458412255
#   Pearson Correlation: 0.756596464465841
# --------------------------------------------------
# Metrics for synthetic data 2:
#   MSE: 0.0010271834184191863
#   Cosine Similarity: 0.8383787651137826
#   Pearson Correlation: 0.6042431001741915
# --------------------------------------------------
# Metrics for synthetic data 3:
#   MSE: 0.001027188644345713
#   Cosine Similarity: 0.923818875754559
#   Pearson Correlation: 0.8372464357427236
# --------------------------------------------------
# Metrics for synthetic data 4:
#   MSE: 0.0010271844816685833
#   Cosine Similarity: 0.7685870572395135
#   Pearson Correlation: 0.7490383025330211
# --------------------------------------------------
# Metrics for synthetic data 5:
#   MSE: 0.0010271923506916135
#   Cosine Similarity: 0.8955484198659686
#   Pearson Correlation: 0.7503547482996759
# --------------------------------------------------
# Metrics for synthetic data 6:
#   MSE: 0.0010271791967126325
#   Cosine Similarity: 0.8823246053514412
#   Pearson Correlation: 0.7761981428151414
# --------------------------------------------------
# Metrics for synthetic data 7:
#   MSE: 0.001027176323914991
#   Cosine Similarity: 0.8081627764551407
#   Pearson Correlation: 0.8545111044009708
# --------------------------------------------------
# Metrics for synthetic data 8:
#   MSE: 0.0010271857092602902
#   Cosine Similarity: 0.8481374407017
#   Pearson Correlation: 0.6060850514280753
# --------------------------------------------------
# Metrics for synthetic data 9:
#   MSE: 0.0010271746077370047
#   Cosine Similarity: 0.9433771246637334
#   Pearson Correlation: 0.7605514177767274
# --------------------------------------------------
# Metrics for synthetic data 10:
#   MSE: 0.001027186085569101
#   Cosine Similarity: 0.8327229980260317
#   Pearson Correlation: 0.7419445910689542
# --------------------------------------------------
# Metrics for synthetic data 11:
#   MSE: 0.0010271703415592217
#   Cosine Similarity: 0.9301414468432021
#   Pearson Correlation: 0.8597258317979062
# --------------------------------------------------
# Metrics for synthetic data 12:
#   MSE: 0.0010271824757607786
#   Cosine Similarity: 0.9051775084591511
#   Pearson Correlation: 0.6721451828359672
# --------------------------------------------------
# Metrics for synthetic data 13:
#   MSE: 0.0010271748978068539
#   Cosine Similarity: 0.9084623678914893
#   Pearson Correlation: 0.658524805333351
# --------------------------------------------------
# Metrics for synthetic data 14:
#   MSE: 0.001027166819128707
#   Cosine Similarity: 0.8523633386488159
#   Pearson Correlation: 0.7487371504430672
# --------------------------------------------------
# Metrics for synthetic data 15:
#   MSE: 0.001027181657820806
#   Cosine Similarity: 0.8035733859262338
#   Pearson Correlation: 0.7268095131228299
# --------------------------------------------------
# Metrics for synthetic data 16:
#   MSE: 0.0010271716107221832
#   Cosine Similarity: 0.868117809631045
#   Pearson Correlation: 0.7289740815469656
# --------------------------------------------------
# Metrics for synthetic data 17:
#   MSE: 0.0010271691911414949
#   Cosine Similarity: 0.7543978303690637
#   Pearson Correlation: 0.7327632259977175
# --------------------------------------------------
# Metrics for synthetic data 18:
#   MSE: 0.0010271830179566727
#   Cosine Similarity: 0.8147926430458012
#   Pearson Correlation: 0.8444160445866981
# --------------------------------------------------
# Metrics for synthetic data 19:
#   MSE: 0.0010271647714296791
#   Cosine Similarity: 0.8535177143956165
#   Pearson Correlation: 0.8381168991075154
# --------------------------------------------------
# Metrics for synthetic data 20:
#   MSE: 0.0010271806136880836
#   Cosine Similarity: 0.9189470191624544
#   Pearson Correlation: 0.7963916569250131
# --------------------------------------------------
# Metrics for synthetic data 21:
#   MSE: 0.001027164370646119
#   Cosine Similarity: 0.7518266051048993
#   Pearson Correlation: 0.6683353197831772
# --------------------------------------------------
# Metrics for synthetic data 22:
#   MSE: 0.0010271801830834609
#   Cosine Similarity: 0.8016894881333082
#   Pearson Correlation: 0.7270388479453535
# --------------------------------------------------
# Metrics for synthetic data 23:
#   MSE: 0.0010271863353686853
#   Cosine Similarity: 0.8153801244267592
#   Pearson Correlation: 0.6296844595133034
# --------------------------------------------------
# Metrics for synthetic data 24:
#   MSE: 0.0010271737769295614
#   Cosine Similarity: 0.8907929602699232
#   Pearson Correlation: 0.6234351969631249
# --------------------------------------------------
# Metrics for synthetic data 25:
#   MSE: 0.0010271675532936627
#   Cosine Similarity: 0.8669148910754061
#   Pearson Correlation: 0.8826051360859557
# --------------------------------------------------
# Metrics for synthetic data 26:
#   MSE: 0.001027186200895569
#   Cosine Similarity: 0.7773432361009377
#   Pearson Correlation: 0.6377537067234907
# --------------------------------------------------
# Metrics for synthetic data 27:
#   MSE: 0.0010271746083513878
#   Cosine Similarity: 0.8692994183176057
#   Pearson Correlation: 0.7321453990416567
# --------------------------------------------------
# Metrics for synthetic data 28:
#   MSE: 0.0010271955350577555
#   Cosine Similarity: 0.940880181129293
#   Pearson Correlation: 0.6388887981467558
# --------------------------------------------------
# Metrics for synthetic data 29:
#   MSE: 0.0010271721637079873
#   Cosine Similarity: 0.8002134777886942
#   Pearson Correlation: 0.8471358818530641
# --------------------------------------------------
# Metrics for synthetic data 30:
#   MSE: 0.0010271779705154445
#   Cosine Similarity: 0.8205882418182296
#   Pearson Correlation: 0.8956522475554887
# --------------------------------------------------
# Metrics for synthetic data 31:
#   MSE: 0.0010271917775027935
#   Cosine Similarity: 0.9336719495218754
#   Pearson Correlation: 0.7400851288835012
# --------------------------------------------------
# Metrics for synthetic data 32:
#   MSE: 0.001027182283629092
#   Cosine Similarity: 0.8118976534510701
#   Pearson Correlation: 0.7660865215460525
# --------------------------------------------------
# Metrics for synthetic data 33:
#   MSE: 0.0010271724875390233
#   Cosine Similarity: 0.8876795597687632
#   Pearson Correlation: 0.7286427723497545
# --------------------------------------------------
# Metrics for synthetic data 34:
#   MSE: 0.0010271831489792576
#   Cosine Similarity: 0.7813679170118586
#   Pearson Correlation: 0.6310495475355192
# --------------------------------------------------
# Metrics for synthetic data 35:
#   MSE: 0.0010271813973002657
#   Cosine Similarity: 0.766946396954966
#   Pearson Correlation: 0.6249494883804523
# --------------------------------------------------
# Metrics for synthetic data 36:
#   MSE: 0.0010271695204615585
# ...
# --------------------------------------------------
# Metrics for synthetic data 19:
#   MSE: 0.00042160162483504294
#   Cosine Similarity: 0.8164569800232709
#   Pearson Correlation: 0.869950801262322
# --------------------------------------------------
# Metrics for synthetic data 20:
#   MSE: 0.0004217837935952239
#   Cosine Similarity: 0.8632923725774589
#   Pearson Correlation: 0.6790212216040353
# --------------------------------------------------
# Metrics for synthetic data 21:
#   MSE: 0.0004217807357155655
#   Cosine Similarity: 0.7631702944004898
#   Pearson Correlation: 0.6610737984195337
# --------------------------------------------------
# Metrics for synthetic data 22:
#   MSE: 0.0004216703259829695
#   Cosine Similarity: 0.9289689793887379
#   Pearson Correlation: 0.7534222683783567
# --------------------------------------------------
# Metrics for synthetic data 23:
#   MSE: 0.0004217395747599519
#   Cosine Similarity: 0.896788037172369
#   Pearson Correlation: 0.6109167602344082
# --------------------------------------------------
# Metrics for synthetic data 24:
#   MSE: 0.00042169535920916803
#   Cosine Similarity: 0.7778481463633181
#   Pearson Correlation: 0.786166802852681
# --------------------------------------------------
# Metrics for synthetic data 25:
#   MSE: 0.0004216753520583066
#   Cosine Similarity: 0.9242897659565033
#   Pearson Correlation: 0.6440347836024611
# --------------------------------------------------
# Metrics for synthetic data 26:
#   MSE: 0.00042177459139660533
#   Cosine Similarity: 0.8788965495779032
#   Pearson Correlation: 0.8783827741868251
# --------------------------------------------------
# Metrics for synthetic data 27:
#   MSE: 0.00042188346476465614
#   Cosine Similarity: 0.7542834769517411
#   Pearson Correlation: 0.8195292327989916
# --------------------------------------------------
# Metrics for synthetic data 28:
#   MSE: 0.0004217615806822892
#   Cosine Similarity: 0.7595157027845952
#   Pearson Correlation: 0.7677598651986214
# --------------------------------------------------
# Metrics for synthetic data 29:
#   MSE: 0.0004218211053145585
#   Cosine Similarity: 0.8531408529531128
#   Pearson Correlation: 0.6531690595160605
# --------------------------------------------------
# Metrics for synthetic data 30:
#   MSE: 0.00042195876901834564
#   Cosine Similarity: 0.75279661616324
#   Pearson Correlation: 0.6271340714255978
# --------------------------------------------------
# Metrics for synthetic data 31:
#   MSE: 0.0004217053194444625
#   Cosine Similarity: 0.9157074294796663
#   Pearson Correlation: 0.7053261012071236
# --------------------------------------------------
# Metrics for synthetic data 32:
#   MSE: 0.00042177201063748704
#   Cosine Similarity: 0.8054656738887452
#   Pearson Correlation: 0.6370630392715291
# --------------------------------------------------
# Metrics for synthetic data 33:
#   MSE: 0.0004218572093727577
#   Cosine Similarity: 0.8976268926897347
#   Pearson Correlation: 0.7593820075228646
# --------------------------------------------------
# Metrics for synthetic data 34:
#   MSE: 0.0004217021408641779
#   Cosine Similarity: 0.8284804691621928
#   Pearson Correlation: 0.8178266081037078
# --------------------------------------------------
# Metrics for synthetic data 35:
#   MSE: 0.0004217858807623316
#   Cosine Similarity: 0.8491610145190468
#   Pearson Correlation: 0.7499661224233456
# --------------------------------------------------
# Metrics for synthetic data 36:
#   MSE: 0.00042172161598610924
#   Cosine Similarity: 0.9067486011489282
#   Pearson Correlation: 0.8200834105263146
# --------------------------------------------------
# Metrics for synthetic data 37:
#   MSE: 0.0004216525034497206
#   Cosine Similarity: 0.8224053571070622
#   Pearson Correlation: 0.8964758574806306
# --------------------------------------------------
# Metrics for synthetic data 38:
#   MSE: 0.0004219634825796345
#   Cosine Similarity: 0.8353849390908534
#   Pearson Correlation: 0.8801110681053435
# --------------------------------------------------
# Metrics for synthetic data 39:
#   MSE: 0.00042185040198099047
#   Cosine Similarity: 0.9458958496650325
#   Pearson Correlation: 0.6438764018720297
# --------------------------------------------------
# Metrics for synthetic data 40:
#   MSE: 0.00042207018579185307
#   Cosine Similarity: 0.8681425301605982
#   Pearson Correlation: 0.7480937052826621
# --------------------------------------------------
# Metrics for synthetic data 41:
#   MSE: 0.0004217598442977796
#   Cosine Similarity: 0.780515517754901
#   Pearson Correlation: 0.6769040350614239
# --------------------------------------------------
# Metrics for synthetic data 42:
#   MSE: 0.00042178478863234
#   Cosine Similarity: 0.9306923872390399
#   Pearson Correlation: 0.8663155959720952
# --------------------------------------------------
# Metrics for synthetic data 43:
#   MSE: 0.00042173688832931124
#   Cosine Similarity: 0.7694442897608371
#   Pearson Correlation: 0.6088932113843523
# --------------------------------------------------
# Metrics for synthetic data 44:
#   MSE: 0.000421566664634483
#   Cosine Similarity: 0.8632745147036727
#   Pearson Correlation: 0.7823182977154908
# --------------------------------------------------
# Metrics for synthetic data 45:
#   MSE: 0.0004217776716668044
#   Cosine Similarity: 0.8500749487078153
#   Pearson Correlation: 0.837419572697033
# --------------------------------------------------
# Metrics for synthetic data 46:
#   MSE: 0.00042174806219023186
#   Cosine Similarity: 0.7591888168395766
#   Pearson Correlation: 0.6084073664341406
# --------------------------------------------------
# Metrics for synthetic data 47:
#   MSE: 0.0004216840536094162
#   Cosine Similarity: 0.8650161303874596
#   Pearson Correlation: 0.6578802249869413
# --------------------------------------------------
# Metrics for synthetic data 48:
#   MSE: 0.00042170985906113954
#   Cosine Similarity: 0.7693001917646912
#   Pearson Correlation: 0.7203872672899675
# --------------------------------------------------
# Metrics for synthetic data 49:
#   MSE: 0.000421792868834901
#   Cosine Similarity: 0.8329261928242133
#   Pearson Correlation: 0.6451565037513965
# --------------------------------------------------
# Metrics for synthetic data 50:
#   MSE: 0.0004216799337561412
#   Cosine Similarity: 0.890632919204436
#   Pearson Correlation: 0.8092096141201665
# --------------------------------------------------
# Metrics for synthetic data 51:
#   MSE: 0.0004218320781117066
#   Cosine Similarity: 0.7524577547041066
#   Pearson Correlation: 0.635169451959239
# --------------------------------------------------
# Metrics for synthetic data 52:
#   MSE: 0.00042168574227590224
#   Cosine Similarity: 0.7715635795299495
#   Pearson Correlation: 0.6411807739380448
# --------------------------------------------------
# Metrics for synthetic data 53:
#   MSE: 0.000421541181181722
#   Cosine Similarity: 0.7704832137911194
#   Pearson Correlation: 0.7043998353571693
# --------------------------------------------------
# Metrics for synthetic data 54:
#   MSE: 0.0004216477331254015
#   Cosine Similarity: 0.8228162696662876
#   Pearson Correlation: 0.7218633422500096
# --------------------------------------------------
# Metrics for synthetic data 55:
#   MSE: 0.00042179857077215066
#   Cosine Similarity: 0.7798948254815646
#   Pearson Correlation: 0.6059522126770165
# --------------------------------------------------
# Metrics for synthetic data 56:
#   MSE: 0.00042170138685956957
#   Cosine Similarity: 0.9341487024170124
#   Pearson Correlation: 0.8246672344962553
# --------------------------------------------------
# Metrics for synthetic data 57:
#   MSE: 0.0004216426808769886
#   Cosine Similarity: 0.8992829729272872
#   Pearson Correlation: 0.6481358872003375
# --------------------------------------------------
# Metrics for synthetic data 58:
#   MSE: 0.0004217283699509292
#   Cosine Similarity: 0.8306382460515166
#   Pearson Correlation: 0.7363988480210973
# --------------------------------------------------
# Metrics for synthetic data 59:
#   MSE: 0.0004216168671113667
#   Cosine Similarity: 0.8812184347539489
#   Pearson Correlation: 0.6702170673150537
# --------------------------------------------------
# Metrics for synthetic data 60:
#   MSE: 0.00042180833995253826
#   Cosine Similarity: 0.7758112529326063
#   Pearson Correlation: 0.647522366140737
# --------------------------------------------------
# Metrics for synthetic data 61:
#   MSE: 0.00042182193523289136
#   Cosine Similarity: 0.9220319418546514
#   Pearson Correlation: 0.8369262253288565
# --------------------------------------------------
# Metrics for synthetic data 62:
#   MSE: 0.00042185453284763265
#   Cosine Similarity: 0.8832707202970325
#   Pearson Correlation: 0.7077385350490536
# --------------------------------------------------
# Metrics for synthetic data 63:
#   MSE: 0.00042181130229111436
#   Cosine Similarity: 0.8195073366756468
#   Pearson Correlation: 0.636160387591273
# --------------------------------------------------
# Metrics for synthetic data 64:
#   MSE: 0.0004217330196841894
#   Cosine Similarity: 0.8952289726703068
#   Pearson Correlation: 0.7286807962825987
# --------------------------------------------------
# Metrics for synthetic data 65:
#   MSE: 0.00042184506023916675
#   Cosine Similarity: 0.9219842307812329
#   Pearson Correlation: 0.7418211215312692
# --------------------------------------------------
# Metrics for synthetic data 66:
#   MSE: 0.0004219360000306224
#   Cosine Similarity: 0.7901473503187042
#   Pearson Correlation: 0.6315295020457258
# --------------------------------------------------
# Metrics for synthetic data 67:
#   MSE: 0.0004215989519487584
#   Cosine Similarity: 0.8914370451860364
#   Pearson Correlation: 0.7004776366274117
# --------------------------------------------------
# Metrics for synthetic data 68:
#   MSE: 0.00042173114621727657
#   Cosine Similarity: 0.8914717651177864
#   Pearson Correlation: 0.7328299921887691
# --------------------------------------------------
# Metrics for synthetic data 69:
#   MSE: 0.0004219348274505276
#   Cosine Similarity: 0.8317534503780123
#   Pearson Correlation: 0.8584854891886692
# --------------------------------------------------
# Metrics for synthetic data 70:
#   MSE: 0.00042192284957549196
#   Cosine Similarity: 0.8701178412335309
#   Pearson Correlation: 0.8336448951661525
# --------------------------------------------------
# Metrics for synthetic data 71:
#   MSE: 0.00042170084355283094
#   Cosine Similarity: 0.8695830877134556
#   Pearson Correlation: 0.7931384357220241
# --------------------------------------------------
# Metrics for synthetic data 72:
#   MSE: 0.0004219004915566403
#   Cosine Similarity: 0.752488035875353
#   Pearson Correlation: 0.6730503072845238
# --------------------------------------------------
# Metrics for synthetic data 73:
#   MSE: 0.00042169973408720383
#   Cosine Similarity: 0.8516488462709574
#   Pearson Correlation: 0.875970539349216
# --------------------------------------------------
# Metrics for synthetic data 74:
#   MSE: 0.0004217941315290031
#   Cosine Similarity: 0.8019049851810846
#   Pearson Correlation: 0.8362780004081214
# --------------------------------------------------
# Metrics for synthetic data 75:
#   MSE: 0.00042177669258971736
#   Cosine Similarity: 0.898485260198127
#   Pearson Correlation: 0.6012357268320266
# --------------------------------------------------
# Metrics for synthetic data 76:
#   MSE: 0.0004216518982399025
#   Cosine Similarity: 0.8572499871858679
#   Pearson Correlation: 0.87161518962802
# --------------------------------------------------
# Metrics for synthetic data 77:
#   MSE: 0.00042167494845549
#   Cosine Similarity: 0.784771570594848
#   Pearson Correlation: 0.6406662135433077
# --------------------------------------------------
# Metrics for synthetic data 78:
#   MSE: 0.000421900031538232
#   Cosine Similarity: 0.8389417165739255
#   Pearson Correlation: 0.6357216469938684
# --------------------------------------------------
# Metrics for synthetic data 79:
#   MSE: 0.00042187538159413487
#   Cosine Similarity: 0.8796070526688631
#   Pearson Correlation: 0.7053307364945929
# --------------------------------------------------
# Metrics for synthetic data 80:
#   MSE: 0.00042174302502963936
#   Cosine Similarity: 0.7747785264104511
#   Pearson Correlation: 0.7072546791384905
# --------------------------------------------------
# Metrics for synthetic data 81:
#   MSE: 0.00042174640296924047
#   Cosine Similarity: 0.756072763494977
#   Pearson Correlation: 0.7028048366874278
# --------------------------------------------------
# Metrics for synthetic data 82:
#   MSE: 0.0004218882838591912
#   Cosine Similarity: 0.7538998691954006
#   Pearson Correlation: 0.8792037323352986
# --------------------------------------------------
# Metrics for synthetic data 83:
#   MSE: 0.0004217398285605307
#   Cosine Similarity: 0.7971158629063566
#   Pearson Correlation: 0.684716341068173
# --------------------------------------------------
# Metrics for synthetic data 84:
#   MSE: 0.00042172110951371706
#   Cosine Similarity: 0.9221797110786822
#   Pearson Correlation: 0.7085086846123636
# --------------------------------------------------
# Metrics for synthetic data 85:
#   MSE: 0.0004217105862663753
#   Cosine Similarity: 0.863065710981704
#   Pearson Correlation: 0.6650118170259535
# --------------------------------------------------
# Metrics for synthetic data 86:
#   MSE: 0.00042169819983516694
#   Cosine Similarity: 0.7645998128055809
#   Pearson Correlation: 0.6892613723645812
# --------------------------------------------------
# Metrics for synthetic data 87:
#   MSE: 0.000421699259753301
#   Cosine Similarity: 0.8062317010227414
#   Pearson Correlation: 0.6644594799973176
# --------------------------------------------------
# Metrics for synthetic data 88:
#   MSE: 0.000421777594752536
#   Cosine Similarity: 0.8127400409799217
#   Pearson Correlation: 0.6726081950283771
# --------------------------------------------------
# Metrics for synthetic data 89:
#   MSE: 0.00042169992245903607
#   Cosine Similarity: 0.9068428180552999
#   Pearson Correlation: 0.7788329731991134
# --------------------------------------------------
# Metrics for synthetic data 90:
#   MSE: 0.00042180220964987215
#   Cosine Similarity: 0.8492536114163557
#   Pearson Correlation: 0.7816007887417499
# --------------------------------------------------
# Metrics for synthetic data 91:
#   MSE: 0.0004216493048785562
#   Cosine Similarity: 0.904923875342747
#   Pearson Correlation: 0.8502817583770675
# --------------------------------------------------
# Metrics for synthetic data 92:
#   MSE: 0.0004218483224256888
#   Cosine Similarity: 0.7741635212183342
#   Pearson Correlation: 0.7996078790133825
# --------------------------------------------------
# Metrics for synthetic data 93:
#   MSE: 0.00042173073242955715
#   Cosine Similarity: 0.9415873094859142
#   Pearson Correlation: 0.8598525158838217
# --------------------------------------------------
# Metrics for synthetic data 94:
#   MSE: 0.0004218340038867159
#   Cosine Similarity: 0.7830362259598709
#   Pearson Correlation: 0.6437884673787234
# --------------------------------------------------
# Metrics for synthetic data 95:
#   MSE: 0.00042172470931258485
#   Cosine Similarity: 0.8518361604177368
#   Pearson Correlation: 0.7655503704589623
# --------------------------------------------------
# Metrics for synthetic data 96:
#   MSE: 0.00042161774669595284
#   Cosine Similarity: 0.8421084097063085
#   Pearson Correlation: 0.8393512617405049
# --------------------------------------------------
# Metrics for synthetic data 97:
#   MSE: 0.0004218253124723812
#   Cosine Similarity: 0.9040217932917185
#   Pearson Correlation: 0.6597047889354108
# --------------------------------------------------
# Metrics for synthetic data 98:
#   MSE: 0.0004217148675634239
#   Cosine Similarity: 0.8787720326120575
#   Pearson Correlation: 0.615905398252079
# --------------------------------------------------
# Metrics for synthetic data 99:
#   MSE: 0.0004219301069429732
#   Cosine Similarity: 0.7613280390080672
#   Pearson Correlation: 0.6035825034907719
# --------------------------------------------------
# Metrics for synthetic data 100:
#   MSE: 0.0004217951074363652
#   Cosine Similarity: 0.9178376044747227
#   Pearson Correlation: 0.6215413427518716
# --------------------------------------------------
# Synthetic data generation for folder 'Electrographic_Seizures' is complete!
# All synthetic data generation complete!
